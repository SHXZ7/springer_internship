# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio

# %%
import pandas as pd

df = pd.read_csv('output/referral_report.csv')  # correct for .xlsx
df.head()
# Out:
#                         referral_id          referral_at    referral_source  \
# 0  9331c8f144dad5a3b8e4a10467b4343a  2024-05-01 12:17:31  Draft Transaction
# 1  6371079a92bcbf0c16ae5fcdf4fc9c10  2024-04-22 22:04:57       User Sign Up
# 2  a49105b02e690472452527663559d97a  2024-05-02 14:10:16  Draft Transaction
# 3  fcb804c8ff24e5b2974a7e965ebea5e8  2024-04-18 10:56:22       User Sign Up
# 4  9e9324e6fde29bb0d230654b38ccfdd4  2024-05-14 13:17:03  Draft Transaction
#
#   referral_source_category  user_referral_status_id     description  \
# 0                  Offline                        1        Menunggu
# 1                   Online                        2        Berhasil
# 2                  Offline                        3  Tidak Berhasil
# 3                   Online                        2        Berhasil
# 4                  Offline                        2        Berhasil
#
#    referral_reward_id  reward_type  reward_value is_reward_granted  ...  \
# ...
